# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as plt

# %%
pokemon_data_orig = pd.read_json("output/pokemon_data_orig.json")
pokemon_forms_data_orig = pd.read_json("output/pokemon_forms_data_orig.json")
pokemon_species_data_orig = pd.read_json("output/pokemon_species_data_orig.json")
ability_data_orig = pd.read_json("output/ability_data_orig.json")
item_data_orig = pd.read_json("output/item_data_orig.json")

# %%
pokemon_data_orig.head()
# Out:
#                                            abilities  base_experience
# 0  [{'ability': {'name': 'overgrow', 'url': 'http...             64.0  \
# 1  [{'ability': {'name': 'overgrow', 'url': 'http...            142.0
# 2  [{'ability': {'name': 'overgrow', 'url': 'http...            263.0
# 3  [{'ability': {'name': 'blaze', 'url': 'https:/...             62.0
# 4  [{'ability': {'name': 'blaze', 'url': 'https:/...            142.0
#
#                                                forms
# 0  [{'name': 'bulbasaur', 'url': 'https://pokeapi...  \
# 1  [{'name': 'ivysaur', 'url': 'https://pokeapi.c...
# 2  [{'name': 'venusaur', 'url': 'https://pokeapi....
# 3  [{'name': 'charmander', 'url': 'https://pokeap...
# 4  [{'name': 'charmeleon', 'url': 'https://pokeap...
#
#                                         game_indices  height held_items  id
# 0  [{'game_index': 153, 'version': {'name': 'red'...       7         []   1  \
# ...

# %%
pokemon_data_orig
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.4/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/.pyenv/versions/3.9.4/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.9.4/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...
